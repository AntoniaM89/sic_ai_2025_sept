# %% [markdown]
# <a href="https://colab.research.google.com/github/AntoniaM89/sic_ai_2025_sept/blob/main/1_introduccion/contribuciones_estudiantes/clase4_Chapter3__244_265.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# paginas 244-258

# %% [markdown]
# En el siguiente código se crea un diccionario donde la clave es el nombre de las columnas (name, math, etc) y cada valor es una lista de elementos que corresponden a cada fila y luego se transforma ese diccionario en un data frame

# %%
exam_data = {"name" : ["stu1", "stu2", "stu3"],
             "math" : [90, 80, 70],
             "eng" : [98, 89, 95],
             "mus" : [85, 95, 100],
             "phy" : [100, 90, 90]}
df = pd.DataFrame(exam_data)
df
# Out:
#    name  math  eng  mus  phy
# 0  stu1    90   98   85  100
# 1  stu2    80   89   95   90
# 2  stu3    70   95  100   90

# %% [markdown]
# En el siguiente código muestra donde inicia el índice, donde termina y los pasos

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %% [markdown]
# El siguiente código hace que name sea el índice del data frame

# %%
df.set_index("name", inplace=True)
df
# Out:
#       math  eng  mus  phy
# name
# stu1    90   98   85  100
# stu2    80   89   95   90
# stu3    70   95  100   90

# %% [markdown]
# El siguiente código asigna el valor 80 en la posición 0,3

# %%
df.iloc[0,3] = 80
df
# Out:
#       math  eng  mus  phy
# name
# stu1    90   98   85   80
# stu2    80   89   95   90
# stu3    70   95  100   90

# %% [markdown]
# Es lo mismo que el código anterior pero se utiliza el nombre de las columnas y filas en vez de número de posición

# %%
df.loc["stu1", "phy"] = 90
df
# Out:
#       math  eng  mus  phy
# name
# stu1    90   98   85   90
# stu2    80   89   95   90
# stu3    70   95  100   90

# %%
df.loc["stu1", "phy"] = 100
df
# Out:
#       math  eng  mus  phy
# name
# stu1    90   98   85  100
# stu2    80   89   95   90
# stu3    70   95  100   90

# %% [markdown]
# El siguiente código cambia el valor de dos celdas segun nombre de filas y columnas

# %%
df.loc["stu1",["mus", "phy"]] = 50
df
# Out:
#       math  eng  mus  phy
# name
# stu1    90   98   50   50
# stu2    80   89   95   90
# stu3    70   95  100   90

# %% [markdown]
# El siguiente código, asigna dos valores distintos a dos celdas distintas

# %%
df.loc["stu1",["mus", "phy"]] = 100, 100
df
# Out:
#       math  eng  mus  phy
# name
# stu1    90   98  100  100
# stu2    80   89   95   90
# stu3    70   95  100   90

# %% [markdown]
# Vuelve al nombre inicial del df, en este caso números en vez de name

# %%
df.reset_index(inplace=True)
df
# Out:
#    name  math  eng  mus  phy
# 0  stu1    90   98  100  100
# 1  stu2    80   89   95   90
# 2  stu3    70   95  100   90

# %% [markdown]
# El siguiente código cambia el valor de las filas por columnas y columnas por filas

# %%
dff=df.transpose()
dff
# Out:
#          0     1     2
# name  stu1  stu2  stu3
# math    90    80    70
# eng     98    89    95
# mus    100    95   100
# phy    100    90    90

# %% [markdown]
# Vuelve a su forma original

# %%
dfff = dff.T
dfff
# Out:
#    name math eng  mus  phy
# 0  stu1   90  98  100  100
# 1  stu2   80  89   95   90
# 2  stu3   70  95  100   90

# %% [markdown]
# PAGINAS 252-259

# %%
"""Transposición con método:
Para cambiar filas por columnas
"""
import pandas as pd

# DataFrame de ejemplo
data = {
    "stu1": [90, 98, 100, 100],
    "stu2": [80, 89, 95, 90],
    "stu3": [70, 95, 100, 90]
}
df = pd.DataFrame(data, index=["math", "eng", "mus", "phy"])

# Transposición con el método
dff = df.transpose()   # o df.T
print(dff)
# Out:
#       math  eng  mus  phy
# stu1    90   98  100  100
# stu2    80   89   95   90
# stu3    70   95  100   90

# %%
"""
Transposición con atributo .T
Es un atajo de transpose(). Devuelve el mismo resultado que el ejercicio anterior.
"""
dff2 = df.T
print(dff2)
# Out:
#       math  eng  mus  phy
# stu1    90   98  100  100
# stu2    80   89   95   90
# stu3    70   95  100   90

# %%
"""Usar una columna como indice
Permite identificar filas por nombre en lugar que por número
"""
# Crear un DataFrame con columna 'name'
data = {
    "name": ["stu1", "stu2", "stu3"],
    "math": [90, 80, 70],
    "eng": [98, 89, 95],
    "mus": [100, 95, 100],
    "phy": [100, 90, 90]
}
df = pd.DataFrame(data)

# Usar 'name' como índice
df2 = df.set_index("name")
print(df2)
# Out:
#       math  eng  mus  phy
# name
# stu1    90   98  100  100
# stu2    80   89   95   90
# stu3    70   95  100   90

# %%
"""Multiindice
Crea un ejemplo jerárquico
"""
# Ejemplo multiíndice
arrays = [
    ["stu1", "stu1", "stu2", "stu2"],
    ["math", "eng", "math", "eng"]
]
index = pd.MultiIndex.from_arrays(arrays, names=("student", "subject"))

scores = [90, 98, 80, 89]
df = pd.DataFrame(scores, index=index, columns=["score"])
print(df)
# Out:
#                  score
# student subject
# stu1    math        90
#         eng         98
# stu2    math        80
#         eng         89

# %%
"""Reindexación
Se agregan nuevas filas y se rellenan con 0
"""
# Crear DataFrame simple
data = {"c1": [10, 20, 30]}
df = pd.DataFrame(data, index=["r0", "r1", "r2"])

# Reindexar con nuevos índices
df2 = df.reindex(["r0", "r1", "r2", "r3", "r4"])
print(df2)
# Out:
#       c1
# r0  10.0
# r1  20.0
# r2  30.0
# r3   NaN
# r4   NaN

# %%
"""Resetear índice
Convierte el índice en una columna y vuelve al índice entero por defecto.

"""
# Resetear índice a numérico
df_reset = df2.reset_index()
print(df_reset)
# Out:
#   index    c1
# 0    r0  10.0
# 1    r1  20.0
# 2    r2  30.0
# 3    r3   NaN
# 4    r4   NaN

# %%
"""Ordenar índice
Permite organizar el DataFrame según los índices.
"""
# Ordenar índice en orden descendente
df_sorted = df2.sort_index(ascending=False)
print(df_sorted)
# Out:
#       c1
# r4   NaN
# r3   NaN
# r2  30.0
# r1  20.0
# r0  10.0

# %%
"""Ordenar por columna
Ordena el DataFrame en función de los valores de una columna.
"""
# Crear un DataFrame con varias columnas
data = {"c1": [10, 40, 20], "c2": [30, 20, 50]}
df = pd.DataFrame(data, index=["r0", "r1", "r2"])

# Ordenar por valores de columna c1 (descendente)
df_sorted = df.sort_values(by="c1", ascending=False)
print(df_sorted)
# Out:
#     c1  c2
# r1  40  20
# r2  20  50
# r0  10  30

# %% [markdown]
# PAGINAS 259-265
#
#
#
# paginas 260, 262 y 264 son lo mismo

# %%
import pandas as pd
dict_data = {'c0':[1,2,3], 'c1':[4,5,6], 'c2':[7,8,9], 'c3':[10,11,12], 'c4':[13,14,15]}
df = pd.DataFrame(dict_data, index=['r0', 'r1', 'r2'])
df
# Out:
#     c0  c1  c2  c3  c4
# r0   1   4   7  10  13
# r1   2   5   8  11  14
# r2   3   6   9  12  15

# %%
import numpy as np
#Transpocision del dataframe
new_index = ['r0','r1','r2','r3','r4','r5']
ndf2 = df.reindex(new_index,fill_value=1)#definimos un nuevo conjunto de indices para el df las cuales se van a rellenar de 0
ndf2
# Out:
#     c0  c1  c2  c3  c4
# r0   1   4   7  10  13
# r1   2   5   8  11  14
# r2   3   6   9  12  15
# r3   1   1   1   1   1
# r4   1   1   1   1   1
# r5   1   1   1   1   1

# %%
dict_data = {'c0':[1,2,3], 'c1':[4,5,6], 'c2':[7,8,9], 'c3':[10,11,12], 'c4':[13,14,15]}
df = pd.DataFrame(dict_data, index=['r0', 'r1', 'r2'])
"""se crea un nuevo dataframe con las columnas definidas en dict_data,
se le asignan  indices personalizados para las filas """
df
# Out:
#     c0  c1  c2  c3  c4
# r0   1   4   7  10  13
# r1   2   5   8  11  14
# r2   3   6   9  12  15

# %%
ndf =df.reset_index() #con esta funcion reseteamos el indice a como estaba originalmente
ndf
# Out:
#   index  c0  c1  c2  c3  c4
# 0    r0   1   4   7  10  13
# 1    r1   2   5   8  11  14
# 2    r2   3   6   9  12  15

# %%
ndf = df.sort_index(ascending=True, na_position="first")
"""con esta funcion ordenamos el indice de forma descendente
plus: con na_position podemos subir o bajar los nan con 'first'"""

ndf
# Out:
#     c0  c1  c2  c3  c4
# r0   1   4   7  10  13
# r1   2   5   8  11  14
# r2   3   6   9  12  15

# %%
ndf = df.sort_values(by='c1', ascending=False)
"""Estamos ordenando el dataframe por la columna c1 de forma descendente"""
ndf
# Out:
#     c0  c1  c2  c3  c4
# r2   3   6   9  12  15
# r1   2   5   8  11  14
# r0   1   4   7  10  13
